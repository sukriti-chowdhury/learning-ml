# %% [markdown]
# ##LeetCode DataSet
# It contains the following info:
#
# - **id**: problem id
# - **title**: problem name
# - **description**: problem description
# - **is_premium**: whether the questions requires a premium account
# - **difficulty**: easy, medium, or hard
# - **solution_link**: how often the answer submitted is correct
# - **acceptance_rate**: how often the answer submitted is correct
# - **frequency**: how often the problem is attempted
# - **url**: url to the problem
# - **discuss_count**: how many comments are submitted by users
# - **accepted**: how many times the answer was accepted
# - **submissions**: how many times the answer was submitted
# - **companies**: which companies were tagged as having asked this specific problem
# - **related_topics**: related topics to the current problem
# - **likes**: how many likes the problem got
# - **dislikes**: how many dislikes the problem got
# - **rating**: likes / (likes + dislikes)
# - **asked_by_faang**: whether or not the question was asked by facebook, apple, amazon, google, or netflix
# - **similar_questions**: similar problems with problem name, slug, and difficulty

# %% [markdown]
# ## Loading the Dataset

# %%
# Import the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing CSV file from local device
leetcode_df = pd.read_csv("resources/leetcode_dataset.csv")

# %% [markdown]
# ## Data Exploration

# %%
leetcode_df.head()
# Out:
#    id                                           title  \
# 0   1                                         Two Sum
# 1   2                                 Add Two Numbers
# 2   3  Longest Substring Without Repeating Characters
# 3   4                     Median of Two Sorted Arrays
# 4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# 0                                  /articles/two-sum             46.7
# 1                          /articles/add-two-numbers             35.7
# 2  /articles/longest-substring-without-repeating-...             31.5
# 3              /articles/median-of-two-sorted-arrays             31.4
# 4            /articles/longest-palindromic-substring             30.6
#
#    frequency                                                url  \
# 0      100.0              https://leetcode.com/problems/two-sum
# 1       93.1      https://leetcode.com/problems/add-two-numbers
# 2       90.9  https://leetcode.com/problems/longest-substrin...
# 3       86.2  https://leetcode.com/problems/median-of-two-so...
# 4       84.7  https://leetcode.com/problems/longest-palindro...
#
#    discuss_count accepted submissions  \
# 0            999     4.1M        8.7M
# 1            999     1.9M        5.2M
# 2            999     2.1M        6.7M
# 3            999   904.7K        2.9M
# 4            999     1.3M        4.1M
#
#                                            companies  \
# 0  Amazon,Google,Apple,Adobe,Microsoft,Bloomberg,...
# 1  Bloomberg,Microsoft,Amazon,Google,Facebook,App...
# 2  Amazon,Bloomberg,Microsoft,Facebook,Apple,Adob...
# 3  Amazon,Goldman Sachs,Facebook,Microsoft,Apple,...
# 4  Amazon,Microsoft,Wayfair,Facebook,Adobe,eBay,G...
#
#                                   related_topics  likes  dislikes  rating  \
# 0                               Array,Hash Table  20217       712      97
# 1                     Linked List,Math,Recursion  11350      2704      81
# 2  Hash Table,Two Pointers,String,Sliding Window  13810       714      95
# 3         Array,Binary Search,Divide and Conquer   9665      1486      87
# 4                     String,Dynamic Programming  10271       670      94
#
#    asked_by_faang                                  similar_questions
# 0               1  [3Sum, /problems/3sum/, Medium], [4Sum, /probl...
# 1               1  [Multiply Strings, /problems/multiply-strings/...
# 2               1  [Longest Substring with At Most Two Distinct C...
# 3               1                                                NaN
# 4               1  [Shortest Palindrome, /problems/shortest-palin...

# %%
# Display basic information about the dataset
leetcode_df.info()

# Describe the dataset to get statistical insights
leetcode_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   object
#  2   description        1825 non-null   object
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   object
#  5   solution_link      987 non-null    object
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   object
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   object
#  11  submissions        1825 non-null   object
#  12  companies          1749 non-null   object
#  13  related_topics     1571 non-null   object
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
#  17  asked_by_faang     1825 non-null   int64
#  18  similar_questions  745 non-null    object
# dtypes: float64(2), int64(7), object(10)
# memory usage: 271.0+ KB
#                 id   is_premium  acceptance_rate    frequency  discuss_count  \
# count  1825.000000  1825.000000      1825.000000  1825.000000    1825.000000
# mean    913.000000     0.218082        53.139616    21.113041     421.435068
# std     526.976438     0.413057        14.778411    22.364741     330.583617
# min       1.000000     0.000000        13.900000     0.000000       9.000000
# 25%     457.000000     0.000000        42.400000     3.100000     150.000000
# 50%     913.000000     0.000000        51.600000    13.500000     292.000000
# 75%    1369.000000     0.000000        62.800000    31.800000     663.000000
# max    1825.000000     1.000000        95.600000   100.000000     999.000000
#
#               likes     dislikes       rating  asked_by_faang
# count   1825.000000  1825.000000  1825.000000     1825.000000
# mean    1050.534795   279.010959    77.391233        0.671233
# std     1512.674013   608.489206    23.317515        0.469894
# min        2.000000     0.000000     7.000000        0.000000
# 25%      217.000000    32.000000    67.000000        0.000000
# 50%      516.000000    92.000000    88.000000        1.000000
# 75%     1200.000000   239.000000    95.000000        1.000000
# max    20217.000000  8900.000000   100.000000        1.000000

# %% [markdown]
# ##Question 1
# ####What is the Shape of the dataset?

# %%
#Solution 1(your code here)
# Let's print the shape of the dataset
print("Shape of the dataset:", leetcode_df.shape)
# Out:
# Shape of the dataset: (1825, 19)

# %% [markdown]
# ##Question 2
# ####What is the datatype of **accepted**, **submissions** and **acceptance rate** fields?
#
# Think: What point should be noted here? Do all columns have the proper datatype?

# %%
#Solution 2(your code here)
# Datatype of columns accepted, submissions, and acceptance rate
print("Data types of specific columns:")
print("Accepted:", leetcode_df['accepted'].dtype)
print("Submissions:", leetcode_df['submissions'].dtype)
print("Acceptance Rate:", leetcode_df['acceptance_rate'].dtype)
print(type(leetcode_df.dtypes))
# Out:
# Data types of specific columns:
# Accepted: object
# Submissions: object
# Acceptance Rate: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ##Question 3
# ####What is the number of missing values corresponding to each field?

# %%
#Solution 3(your code here)
#number of missing values corresponding to each field
leetcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   object
#  2   description        1825 non-null   object
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   object
#  5   solution_link      987 non-null    object
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   object
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   object
#  11  submissions        1825 non-null   object
#  12  companies          1749 non-null   object
#  13  related_topics     1571 non-null   object
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
#  17  asked_by_faang     1825 non-null   int64
#  18  similar_questions  745 non-null    object
# dtypes: float64(2), int64(7), object(10)
# memory usage: 271.0+ KB

# %%
# percentage of missing values corresponding to each field
missing_percentage = leetcode_df.isnull().mean() * 100
missing_percentage
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Percentage of missing values in each column:
# id                    0.000000
# title                 0.000000
# description           0.000000
# is_premium            0.000000
# difficulty            0.000000
# solution_link        45.917808
# acceptance_rate       0.000000
# frequency             0.000000
# url                   0.000000
# discuss_count         0.000000
# accepted              0.000000
# submissions           0.000000
# companies             4.164384
# related_topics       13.917808
# likes                 0.000000
# dislikes              0.000000
# rating                0.000000
# asked_by_faang        0.000000
# similar_questions    59.178082
# dtype: float64

# %% [markdown]
# ##Question 4
# ####What is the cardinality of the columns?

# %%
#Solution 4(your code here)
# Display the cardinality of all the columns
cardinality = leetcode_df.nunique()
print("Cardinality of each column:")
print(cardinality)
# Out:
# Cardinality of each column:
# id                   1825
# title                1825
# description          1670
# is_premium              2
# difficulty              3
# solution_link         987
# acceptance_rate       576
# frequency             619
# url                  1825
# discuss_count         642
# accepted             1098
# submissions          1236
# companies             691
# related_topics        320
# likes                1161
# dislikes              603
# rating                 94
# asked_by_faang          2
# similar_questions     689
# dtype: int64

# %% [markdown]
# ##Question 5
# ####Give 2 inferences from the .describe() of the dataset.

# %%
#Solution 5(your code here)

# Inference 1: Show only numerical with [10, 30, 60] percentiles
leetcode_df.describe(percentiles=[0.1, 0.3, 0.6])
# Out:
#                 id   is_premium  acceptance_rate    frequency  discuss_count  \
# count  1825.000000  1825.000000      1825.000000  1825.000000    1825.000000
# mean    913.000000     0.218082        53.139616    21.113041     421.435068
# std     526.976438     0.413057        14.778411    22.364741     330.583617
# min       1.000000     0.000000        13.900000     0.000000       9.000000
# 10%     183.400000     0.000000        35.200000     0.000000      82.000000
# 30%     548.200000     0.000000        44.220000     4.500000     177.000000
# 50%     913.000000     0.000000        51.600000    13.500000     292.000000
# 60%    1095.400000     0.000000        55.800000    20.040000     396.400000
# max    1825.000000     1.000000        95.600000   100.000000     999.000000
#
#            accepted   submissions         likes     dislikes       rating  \
# count  1.825000e+03  1.825000e+03   1825.000000  1825.000000  1825.000000
# mean   1.054884e+07  1.435690e+07   1050.534795   279.010959    77.391233
# std    1.656531e+07  2.009664e+07   1512.674013   608.489206    23.317515
# min    3.050000e+02  3.430000e+02      2.000000     0.000000     7.000000
# 10%    7.000000e+05  1.200000e+06     89.400000    11.000000    36.000000
# 30%    1.760000e+06  2.812000e+06    259.000000    40.000000    75.000000
# 50%    3.640000e+06  5.600000e+06    516.000000    92.000000    88.000000
# 60%    5.488000e+06  8.460000e+06    698.400000   135.000000    91.000000
# max    9.911000e+07  9.842000e+07  20217.000000  8900.000000   100.000000
#
#        asked_by_faang
# count     1825.000000
# mean         0.671233
# std          0.469894
# min          0.000000
# 10%          0.000000
# 30%          0.000000
# 50%          1.000000
# 60%          1.000000
# max          1.000000

# %%
# Inference 2: Show only categoricals/strings
leetcode_df.describe(include='object')
# Out:
#           title description difficulty solution_link  \
# count      1825        1825       1825          1825
# unique     1825        1670          3           988
# top     Two Sum  SQL Schema     Medium            NA
# freq          1         156        963           838
#
#                                           url companies related_topics  \
# count                                    1825      1749           1571
# unique                                   1825       691            320
# top     https://leetcode.com/problems/two-sum    Google          Array
# freq                                        1       257            134
#
#                                         similar_questions
# count                                                 745
# unique                                                689
# top     [Stone Game V, /problems/stone-game-v/, Hard],...
# freq                                                    4

# %% [markdown]
# ### Question 6
#
# #### Handle the missing values in the columns

# %%
#Solution 6(your code here)
leetcode_df.info()
# Replace null values in the 'difficulty' column with 'Unknown'
leetcode_df['solution_link'].fillna('NA', inplace=True)
leetcode_df.info()
print(leetcode_df['solution_link'].unique())
leetcode_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   object
#  2   description        1825 non-null   object
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   object
#  5   solution_link      1825 non-null   object
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   object
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   float64
#  11  submissions        1825 non-null   float64
#  12  companies          1749 non-null   object
#  13  related_topics     1571 non-null   object
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
#  17  asked_by_faang     1825 non-null   int64
#  18  similar_questions  745 non-null    object
# dtypes: float64(4), int64(7), object(8)
# memory usage: 271.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   object
#  2   description        1825 non-null   object
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   object
#  5   solution_link      1825 non-null   object
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   object
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   float64
#  11  submissions        1825 non-null   float64
#  12  companies          1749 non-null   object
#  13  related_topics     1571 non-null   object
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
#  17  asked_by_faang     1825 non-null   int64
#  18  similar_questions  745 non-null    object
# dtypes: float64(4), int64(7), object(8)
# memory usage: 271.0+ KB
# ['/articles/two-sum' '/articles/add-two-numbers'
#  '/articles/longest-substring-without-repeating-characters'
#  '/articles/median-of-two-sorted-arrays'
#  '/articles/longest-palindromic-substring' '/articles/zigzag-conversion'
#  '/articles/reverse-integer' '/articles/string-to-integer'
#  '/articles/palindrome-number' '/articles/regular-expression-matching'
#  '/articles/container-with-most-water' '/articles/integer-to-roman'
#  '/articles/roman-to-integer' '/articles/longest-common-prefix'
#  '/articles/3sum' '/articles/3sum-closest'
#  '/articles/letter-combinations-of-a-phone-number' '/articles/4sum'
#  '/articles/remove-nth-node-from-end-of-list'
#  '/articles/valid-parentheses' '/articles/merge-two-sorted-lists'
#  '/articles/generate-parentheses' '/articles/merge-k-sorted-list'
#  '/articles/swap-nodes-in-pairs' '/articles/reverse-nodes-in-k-group'
#  '/articles/remove-duplicates-from-sorted-array'
#  '/articles/remove-element' '/articles/implement-strstr'
#  '/articles/divide-integers' 'NA' '/articles/next-permutation'
#  '/articles/longest-valid-parentheses'
#  '/articles/search-in-rotated-sorted-array'
#  '/articles/find-first-and-last-position-of-element-in-sorted-array'
#  '/articles/search-insert-position' '/articles/valid-sudoku'
#  '/articles/sudoku-solver' '/articles/count-and-say'
#  '/articles/combination-sum' '/articles/combination-sum-ii'
#  '/articles/first-missing-positive' '/articles/trapping-rain-water'
#  '/articles/wildcard-matching' '/articles/jump-game-ii'
#  '/articles/permutations' '/articles/permutations-ii'
#  '/articles/rotate-image' '/articles/group-anagrams' '/articles/powx-n'
#  '/articles/n-queens' '/articles/n-queens-ii' '/articles/maximum-subarray'
#  '/articles/spiral-matrix' '/articles/jump-game'
#  '/articles/merge-intervals' '/articles/insert-interval'
#  '/articles/length-of-last-word' '/articles/spiral-matrix-ii'
#  '/articles/permutation-sequence' '/articles/rotate-list'
#  '/articles/unique-paths' '/articles/unique-paths-ii'
#  '/articles/minimum-path-sum' '/articles/plus-one' '/articles/add-binary'
#  '/articles/sqrtx' '/articles/climbing-stairs' '/articles/simplify-path'
#  '/articles/edit-distance' '/articles/set-matrix-zeroes'
#  '/articles/search-in-2d-matrix' '/articles/sort-colors'
#  '/articles/minimum-window-substring' '/articles/combinations'
#  '/articles/subsets' '/articles/word-search'
#  '/articles/remove-duplicates-from-sorted-array-ii'
#  '/articles/search-in-rotated-sorted-array-ii'
#  '/articles/remove-duplicates-from-sorted-list-ii'
#  '/articles/remove-duplicates-from-sorted-list'
#  '/articles/largest-rectangle-in-histogram' '/articles/maximal-rectangle'
#  '/articles/partition-list' '/articles/merge-sorted-arrays'
#  '/articles/decode-ways' '/articles/reverse-linked-list-ii'
#  '/articles/restore-ip-addresses'
#  '/articles/binary-tree-inorder-traversal'
#  '/articles/unique-binary-search-trees-ii'
#  '/articles/unique-binary-search-trees' '/articles/interleaving-strings'
#  '/articles/validate-binary-search-tree'
#  '/articles/recover-binary-search-tree' '/articles/same-tree'
#  '/articles/symmetric-tree' '/articles/binary-tree-level-order-traversal'
#  '/articles/binary-tree-zigzag-level-order-traversal'
#  '/articles/maximum-depth-of-binary-tree'
#  '/articles/construct-binary-tree-from-preorder-and-inorder-traversal'
#  '/articles/construct-binary-tree-from-inorder-and-postorder-traversal'
#  '/articles/binary-tree-level-order-traversal-ii'
#  '/articles/convert-sorted-array-to-bst'
#  '/articles/convert-sorted-list-to-binary-search-tree'
#  '/articles/balanced-binary-tree' '/articles/minimum-depth-of-binary-tree'
#  '/articles/path-sum' '/articles/path-sum-ii'
#  '/articles/flatten-binary-tree-to-linked-list'
#  '/articles/distinct-subsequences'
#  '/articles/populating-next-right-pointers-in-each-node'
#  '/articles/populating-next-right-pointers-in-each-node-ii'
#  '/articles/pascals-triangle' '/articles/pascals-triangle-ii'
#  '/articles/best-time-to-buy-and-sell-stock'
#  '/articles/best-time-to-buy-and-sell-stock-ii'
#  '/articles/best-time-to-buy-and-sell-stock-iii'
#  '/articles/binary-tree-maximum-path-sum' '/articles/valid-palindrome'
#  '/articles/word-ladder' '/articles/longest-consecutive-sequence'
#  '/articles/sum-root-to-leaf-numbers' '/articles/surrounded-regions'
#  '/articles/palindrome-partitioning' '/articles/clone-graph'
#  '/articles/gas-station' '/articles/candy' '/articles/single-number'
#  '/articles/single-number-ii' '/articles/copy-list-with-random-pointer'
#  '/articles/word-break' '/articles/word-break-ii'
#  '/articles/linked-list-cycle' '/articles/linked-list-cycle-ii'
#  '/articles/reorder-list' '/articles/binary-tree-preorder-traversal'
#  '/articles/binary-tree-postorder-traversal' '/articles/lru-cache'
#  '/articles/insertion-sort-list' '/articles/sort-list'
#  '/articles/max-points-on-a-line'
#  '/articles/evaluate-reverse-polish-notation'
#  '/articles/reverse-words-in-a-string'
#  '/articles/maximum-product-subarray'
#  '/articles/find-minimum-in-rotated-sorted-array'
#  '/articles/find-minimum-in-rotated-sorted-array-ii' '/articles/min-stack'
#  '/articles/read-n-characters-given-read4'
#  '/articles/longest-substring-with-at-most-two-distinct-characters'
#  '/articles/intersection-of-two-linked-lists'
#  '/articles/one-edit-distance' '/articles/find-peak-element'
#  '/articles/missing-ranges' '/articles/maximum-gap'
#  '/articles/compare-version-numbers'
#  '/articles/fraction-to-recurring-decimal'
#  '/articles/two-sum-ii-input-array-is-sorted' '/articles/majority-element'
#  '/articles/two-sum-iii-data-structure-design'
#  '/articles/excel-sheet-column-number'
#  '/articles/factorial-trailing-zeroes'
#  '/articles/binary-search-tree-iterator' '/articles/dungeon-game'
#  '/articles/combine-two-tables' '/articles/second-highest-salary'
#  '/articles/largest-number' '/articles/consecutive-numbers'
#  '/articles/employees-earning-more-than-their-managers'
#  '/articles/duplicate-emails' '/articles/customers-who-never-order'
#  '/articles/department-highest-salary'
#  '/articles/department-top-three-salaries'
#  '/articles/reverse-words-in-a-string-ii'
#  '/articles/repeated-dna-sequences'
#  '/articles/best-time-to-buy-and-sell-stock-iv' '/articles/rotate-array'
#  '/articles/reverse-bits' '/articles/number-1-bits'
#  '/articles/delete-duplicate-emails' '/articles/rising-temperature'
#  '/articles/house-robber' '/articles/binary-tree-right-side-view'
#  '/articles/number-of-islands' '/articles/bitwise-and-of-numbers-range'
#  '/articles/happy-number' '/articles/remove-linked-list-elements'
#  '/articles/reverse-linked-list' '/articles/course-schedule'
#  '/articles/implement-trie-prefix-tree'
#  '/articles/minimum-size-subarray-sum' '/articles/course-schedule-ii'
#  '/articles/add-and-search-word' '/articles/word-search-ii'
#  '/articles/house-robber-ii' '/articles/shortest-palindrome'
#  '/articles/kth-largest-element-in-an-array'
#  '/articles/combination-sum-iii' '/articles/contains-duplicate'
#  '/articles/skyline-problem' '/articles/contains-duplicate-ii'
#  '/articles/contains-duplicate-iii' '/articles/maximal-square'
#  '/articles/count-complete-tree-nodes' '/articles/basic-calculator'
#  '/articles/implement-stack-using-queues' '/articles/invert-binary-tree'
#  '/articles/basic-calculator-ii' '/articles/summary-ranges'
#  '/articles/majority-element-ii' '/articles/kth-smallest-element-in-a-bst'
#  '/articles/power-of-two' '/articles/implement-queue-using-stacks'
#  '/articles/number-of-digit-one' '/articles/palindrome-linked-list'
#  '/articles/lowest-common-ancestor-of-a-binary-search-tree'
#  '/articles/lowest-common-ancestor-of-a-binary-tree'
#  '/articles/delete-node-linked-list'
#  '/articles/product-of-array-except-self'
#  '/articles/sliding-window-maximum' '/articles/search-a-2d-matrix-ii'
#  '/articles/valid-anagram' '/articles/shortest-word-distance'
#  '/articles/shortest-word-distance-ii' '/articles/strobogrammatic-number'
#  '/articles/count-univalue-subtrees' '/articles/flatten-2d-vector'
#  '/articles/meeting-rooms' '/articles/meeting-rooms-ii'
#  '/articles/paint-house' '/articles/binary-tree-paths'
#  '/articles/add-digits' '/articles/3sum-smaller'
#  '/articles/single-number-iii' '/articles/graph-valid-tree'
#  '/articles/ugly-number-ii' '/articles/paint-house-ii'
#  '/articles/palindrome-permutation' '/articles/palindrome-permutation-ii'
#  '/articles/missing-number' '/articles/alien-dictionary'
#  '/articles/closest-bst-value' '/articles/encode-and-decode-strings'
#  '/articles/closest-bst-value-ii' '/articles/integer-to-english-words'
#  '/articles/h-index' '/articles/h-index-ii' '/articles/paint-fence'
#  '/articles/find-the-celebrity' '/articles/first-bad-version'
#  '/articles/perfect-squares' '/articles/wiggle-sort'
#  '/articles/zigzag-iterator' '/articles/expression-add-operators'
#  '/articles/move-zeroes' '/articles/peeking-iterator'
#  '/articles/inorder-successor-in-bst' '/articles/walls-and-gates'
#  '/articles/find-the-duplicate-number'
#  '/articles/unique-word-abbreviation' '/articles/game-of-life'
#  '/articles/word-pattern' '/articles/nim-game'
#  '/articles/find-median-from-data-stream' '/articles/best-meeting-point'
#  '/articles/serialize-and-deserialize-binary-tree'
#  '/articles/binary-tree-longest-consecutive-sequence'
#  '/articles/bulls-and-cows' '/articles/longest-increasing-subsequence'
#  '/articles/remove-invalid-parentheses'
#  '/articles/smallest-rectangle-enclosing-black-pixels'
#  '/articles/range-sum-query-immutable'
#  '/articles/range-sum-query-2d-immutable' '/articles/number-of-islands-ii'
#  '/articles/range-sum-query-mutable'
#  '/articles/range-sum-query-2d-mutable'
#  '/articles/best-time-to-buy-and-sell-stock-with-cooldown'
#  '/articles/minimum-height-trees' '/articles/burst-balloons'
#  '/articles/binary-tree-vertical-order-traversal'
#  '/articles/remove-duplicate-letters'
#  '/articles/maximum-product-of-word-lengths'
#  '/articles/generalized-abbreviation' '/articles/coin-change'
#  '/articles/number-of-connected-components-in-an-undirected-graph'
#  '/articles/power-of-three' '/articles/odd-even-linked-list'
#  '/articles/longest-increasing-path-in-a-matrix'
#  '/articles/patching-array'
#  '/articles/verify-preorder-serialization-of-a-binary-tree'
#  '/articles/reconstruct-itinerary'
#  '/articles/increasing-triplet-subsequence' '/articles/palindrome-pairs'
#  '/articles/house-robber-iii' '/articles/counting-bits'
#  '/articles/nested-list-weight-sum'
#  '/articles/longest-substring-with-at-most-k-distinct-characters'
#  '/articles/flatten-nested-iterator' '/articles/power-of-four'
#  '/articles/reverse-string' '/articles/moving-average-from-data-stream'
#  '/articles/top-k-frequent-elements'
#  '/articles/intersection-of-two-arrays'
#  '/articles/intersection-of-two-arrays-ii'
#  '/articles/android-unlock-patterns' '/articles/design-snake-game'
#  '/articles/russian-doll-envelopes' '/articles/logger-rate-limiter'
#  '/articles/bomb-enemy' '/articles/design-hit-counter'
#  '/articles/find-leaves-of-binary-tree' '/articles/valid-perfect-square'
#  '/articles/largest-divisible-subset' '/articles/plus-one-linked-list'
#  '/articles/range-addition' '/articles/sum-of-two-integers'
#  '/articles/guess-number-higher-or-lower'
#  '/articles/guess-higher-or-lower-number-ii'
#  '/articles/wiggle-subsequence' '/articles/combination-sum-iv'
#  '/articles/kth-smallest-element-in-a-sorted-matrix'
#  '/articles/insert-delete-getrandom-o1'
#  '/articles/insert-delete-getrandom-o1-duplicates-allowed'
#  '/articles/linked-list-random-node' '/articles/ransom-note'
#  '/articles/shuffle-an-array'
#  '/articles/first-unique-character-in-a-string'
#  '/articles/find-the-difference' '/articles/is-subsequence'
#  '/articles/utf-8-validation' '/articles/decode-string'
#  '/articles/longest-substring-with-at-least-k-repeating-characters'
#  '/articles/random-pick-index' '/articles/evaluate-division'
#  '/articles/remove-k-digits' '/articles/frog-jump'
#  '/articles/sum-of-left-leaves' '/articles/queue-reconstruction-by-height'
#  '/articles/longest-palindrome' '/articles/split-array-largest-sum'
#  '/articles/fizz-buzz' '/articles/arithmetic-slices'
#  '/articles/third-maximum-number' '/articles/add-strings'
#  '/articles/partition-equal-subset-sum'
#  '/articles/pacific-atlantic-water-flow'
#  '/articles/maximum-xor-of-two-numbers-in-an-array'
#  '/articles/reconstruct-original-digits-from-english'
#  '/articles/word-squares'
#  '/articles/convert-binary-search-tree-to-sorted-doubly-linked-list'
#  '/articles/serialize-and-deserialize-n-ary-tree'
#  '/articles/n-ary-tree-level-order-traversal'
#  '/articles/flatten-a-multilevel-doubly-linked-list'
#  '/articles/encode-n-ary-tree-to-binary-tree'
#  '/articles/number-of-segments-in-a-string'
#  '/articles/non-overlapping-intervals' '/articles/find-right-interval'
#  '/articles/path-sum-iii' '/articles/find-all-anagrams-in-a-string'
#  '/articles/arranging-coins' '/articles/find-all-duplicates-in-an-array'
#  '/articles/string-compression' '/articles/add-two-numbers-ii'
#  '/articles/arithmetic-slices-ii-subsequence'
#  '/articles/find-all-numbers-disappeared-in-an-array'
#  '/articles/serialize-and-deserialize-bst'
#  '/articles/delete-node-in-a-bst' '/articles/sort-characters-by-frequency'
#  '/articles/minimum-number-of-arrows-to-burst-balloons'
#  '/articles/minimum-moves-to-equal-array-elements' '/articles/4sum-ii'
#  '/articles/132-pattern' '/articles/poor-pigs'
#  '/articles/repeated-substring-pattern' '/articles/hamming-distance'
#  '/articles/minimum-moves-to-equal-array-elements-ii'
#  '/articles/island-perimeter' '/articles/count-the-repetitions'
#  '/articles/validate-ip-address' '/articles/implement-rand10-using-rand7'
#  '/articles/matchsticks-to-square' '/articles/ones-and-zeroes'
#  '/articles/number-complement' '/articles/total-hamming-distance'
#  '/articles/generate-random-point-in-a-circle'
#  '/articles/sliding-window-median' '/articles/find-permutation'
#  '/articles/max-consecutive-ones' '/articles/predict-the-winner'
#  '/articles/max-consecutive-ones-ii' '/articles/robot-room-cleaner'
#  '/articles/the-maze' '/articles/reverse-pairs' '/articles/target-sum'
#  '/articles/teemo-attacking' '/articles/greater-element-i'
#  '/articles/random-point-in-non-overlapping-rectangles'
#  '/articles/diagonal-traverse' '/articles/ipo'
#  '/articles/next-greater-element-ii' '/articles/the-maze-ii'
#  '/articles/perfect-number' '/articles/fibonacci-number'
#  '/articles/inorder-successor-in-a-bst-ii'
#  '/articles/super-washing-machines' '/articles/coin-change-ii'
#  '/articles/random-flip-matrix' '/articles/detect-capital'
#  '/articles/longest-uncommon-subsequence-i'
#  '/articles/longest-uncommon-subsequence-ii'
#  '/articles/continuous-subarray-sum'
#  '/articles/longest-word-in-dictionary-through-deletion'
#  '/articles/contiguous-array' '/articles/beautiful-arrangement'
#  '/articles/word-abbreviation' '/articles/random-pick-with-weight'
#  '/articles/k-diff-pairs-in-an-array'
#  '/articles/encode-and-decode-tinyurl'
#  '/articles/construct-binary-tree-from-string'
#  '/articles/complex-number-multiplication'
#  '/articles/convert-bst-to-greater-tree'
#  '/articles/single-element-in-a-sorted-array'
#  '/articles/reverse-string-ii' '/articles/01-matrix'
#  '/articles/diameter-of-binary-tree' '/articles/output-contest-matches'
#  '/articles/boundary-of-binary-tree' '/articles/remove-boxes'
#  '/articles/friend-circles' '/articles/split-array-with-equal-sum'
#  '/articles/binary-tree-longest-consecutive-sequence-ii'
#  '/articles/student-attendance-record-i'
#  '/articles/student-attendance-record-ii' '/articles/optimal-division'
#  '/articles/brick-wall' '/articles/split-concatenated-strings'
#  '/articles/next-greater-element-iii'
#  '/articles/reverse-words-in-a-string-iii'
#  '/articles/maximum-depth-of-n-ary-tree' '/articles/subarray-sum-equals-k'
#  '/articles/array-partition-i'
#  '/articles/longest-line-of-consecutive-one-in-matrix'
#  '/articles/binary-tree-tilt' '/articles/find-the-closest-palindrome'
#  '/articles/array-nesting' '/articles/reshape-the-matrix'
#  '/articles/short-permutation-in-a-long-string'
#  '/articles/maximum-vacation-days' '/articles/median-employee-salary'
#  '/articles/managers-with-at-least-5-direct-reports'
#  '/articles/subtree-of-another-tree' '/articles/squirrel-simulation'
#  '/articles/winning-candidate' '/articles/distribute-candies'
#  '/articles/out-of-boundary-paths' '/articles/employee-bonus'
#  '/articles/get-highest-answer-rate-question'
#  '/articles/find-cumulative-salary-of-an-employee'
#  '/articles/count-student-number-in-departments'
#  '/articles/shortest-unsorted-continous-subarray' '/articles/kill-process'
#  '/articles/delete-operation-for-two-strings'
#  '/articles/find-customer-referee' '/articles/investments-in-2016'
#  '/articles/customer-placing-the-largest-number-of-orders'
#  '/articles/erect-the-fence' '/articles/design-in-memory-file-system'
#  '/articles/n-ary-tree-preorder-traversal'
#  '/articles/n-ary-tree-postorder-traversal' '/articles/tag-validator'
#  '/articles/fraction-additon-and-subtraction' '/articles/valid-square'
#  '/articles/longest-harmonious-subsequence' '/articles/big-countries'
#  '/articles/classes-more-than-5-students'
#  '/articles/friend-requests-i-overall-acceptance-rate'
#  '/articles/range-addition-ii' '/articles/minimum-index-sum-of-two-lists'
#  '/articles/non-negative-integers-without-consecutive-ones'
#  '/articles/human-traffic-of-stadium'
#  '/articles/friend-requests-ii-who-has-most-friend'
#  '/articles/consecutive-available-seats'
#  '/articles/design-compressed-string-iterator'
#  '/articles/can-place-flowers'
#  '/articles/construct-string-from-binary-tree' '/articles/sales-person'
#  '/articles/tree-node' '/articles/find-duplicate-file-in-system'
#  '/articles/triangle-judgement' '/articles/valid-triangle-number'
#  '/articles/shortest-distance-in-a-plane'
#  '/articles/shortest-distance-in-a-line'
#  '/articles/average-salary-departments-vs-company'
#  '/articles/add-bold-tag-in-a-string' '/articles/merge-two-binary-trees'
#  '/articles/students-report-by-geography'
#  '/articles/biggest-single-number' '/articles/not-boring-movies'
#  '/articles/task-scheduler' '/articles/design-circular-queue'
#  '/articles/add-one-row-in-a-tree' '/articles/maximum-distance-in-array'
#  '/articles/minimum-factorization' '/articles/exchange-seats'
#  '/articles/swap-salary' '/articles/maximmum-product-of-three-numbers'
#  '/articles/k-inverse-pairs-array' '/articles/course-schedule-iii'
#  '/articles/design-excel-sum-formula' '/articles/smallest-range'
#  '/articles/sum-of-square-numbers' '/articles/find-derangements'
#  '/articles/design-log-storage' '/articles/exclusive-time-of-functions'
#  '/articles/average-of-levels-in-binary-tree' '/articles/shopping-offers'
#  '/articles/decode-ways-ii' '/articles/solve-the-equation'
#  '/articles/design-search-autocomplete-system'
#  '/articles/maximum-average-subarray'
#  '/articles/maximum-average-subarray-ii' '/articles/set-mismatch'
#  '/articles/maximum-length-of-pair-chain'
#  '/articles/palindromic-substrings' '/articles/replace-words'
#  '/articles/dota2-senate' '/articles/2-keys-keyboard'
#  '/articles/4-keys-keyboard' '/articles/find-duplicate-subtrees'
#  '/articles/two-sum-iv' '/articles/maximum-binary-tree'
#  '/articles/print-binary-tree' '/articles/coin-path'
#  '/articles/judge-route-circle' '/articles/find-k-closest-elements'
#  '/articles/split-array-into-consecutive-subsequences'
#  '/articles/remove-9' '/articles/image-smoother'
#  '/articles/maximum-width-of-binary-tree' '/articles/equal-tree-partition'
#  '/articles/strange-printer' '/articles/non-decreasing-array'
#  '/articles/path-sum-iv' '/articles/beautiful-arrangement-ii'
#  '/articles/kth-smallest-number-in-multiplication-table'
#  '/articles/trim-a-binary-search-tree' '/articles/maximum-swap'
#  '/articles/second-minimum-node-in-a-binary-tree'
#  '/articles/bulb-switcher-ii'
#  '/articles/number-of-longest-increasing-subsequence'
#  '/articles/longest-continuous-increasing-subsequence'
#  '/articles/cutoff-trees-for-golf-event'
#  '/articles/implement-magic-dictionary' '/articles/map-sum-pairs'
#  '/articles/valid-parenthesis-string' '/articles/24-game'
#  '/articles/valid-palindrome-ii' '/articles/next-closest-time'
#  '/articles/baseball-game' '/articles/k-empty-slots'
#  '/articles/redundant-connection' '/articles/redundant-connection-ii'
#  '/articles/repeated-string-match' '/articles/longest-univalue-path'
#  '/articles/knight-probability-in-chessboard'
#  '/articles/maximum-sum-of-3-non-overlapping-intervals'
#  '/articles/employee-importance' '/articles/stickers-to-spell-word'
#  '/articles/top-k-frequent-words'
#  '/articles/binary-number-with-alternating-bits'
#  '/articles/number-of-distinct-islands' '/articles/max-area-of-island'
#  '/articles/count-binary-substrings' '/articles/degree-of-an-array'
#  '/articles/partition-to-k-equal-sum-subsets' '/articles/falling-squares'
#  '/articles/search-in-a-bst' '/articles/insert-into-a-bst'
#  '/articles/search-in-a-sorted-array-of-unknown-size'
#  '/articles/binary-search' '/articles/design-hashset'
#  '/articles/design-hashmap' '/articles/design-linked-list'
#  '/articles/insert-into-a-cyclic-sorted-list' '/articles/to-lower-case'
#  '/articles/random-pick-with-blacklist'
#  '/articles/number-of-distinct-islands-ii'
#  '/articles/minimum-ascii-delete-sum-for-two-strings'
#  '/articles/subarray-product-less-than-k'
#  '/articles/best-time-to-buy-and-sell-stock-with-transaction-fee'
#  '/articles/range-module' '/articles/max-stack'
#  '/articles/1-bit-and-2-bit-characters'
#  '/articles/maximum-length-of-repeated-subarray'
#  '/articles/find-k-th-smallest-pair-distance'
#  '/articles/longest-word-in-dictionary' '/articles/accounts-merge'
#  '/articles/remove-comments' '/articles/candy-crush'
#  '/articles/find-pivot-index' '/articles/split-linked-list-in-parts'
#  '/articles/number-of-atoms' '/articles/minimum-window-subsequence'
#  '/articles/self-dividing-numbers' '/articles/my-calendar-i'
#  '/articles/count-different-palindromic-subsequences'
#  '/articles/my-calendar-ii' '/articles/my-calendar-iii'
#  '/articles/flood-fill' '/articles/sentence-similarity'
#  '/articles/asteroid-collision' '/articles/parse-lisp-expression'
#  '/articles/sentence-similarity-ii' '/articles/monotone-increasing-digits'
#  '/articles/daily-temperatures' '/articles/delete-and-earn'
#  '/articles/cherry-pickup' '/articles/closest-leaf-in-binary-tree'
#  '/articles/network-delay-time'
#  '/articles/find-smallest-letter-greater-than-target'
#  '/articles/prefix-and-suffix-search' '/articles/min-cost-climbing-stairs'
#  '/articles/largest-number-at-least-twice-of-others'
#  '/articles/shortest-completing-word' '/articles/contain-virus'
#  '/articles/number-of-corner-rectangles' '/articles/ip-to-cidr'
#  '/articles/open-the-lock' '/articles/cracking-the-safe'
#  '/articles/reach-a-number' '/articles/pour-water'
#  '/articles/pyramid-transition-matrix'
#  '/articles/set-intersection-size-at-least-two'
#  '/articles/bold-words-in-string' '/articles/employee-free-time'
#  '/articles/find-anagram-mappings' '/articles/special-binary-string'
#  '/articles/prime-number-of-set-bits-in-binary-representation'
#  '/articles/partition-labels' '/articles/largest-plus-sign'
#  '/articles/couples-holding-hands' '/articles/toeplitz-matrix'
#  '/articles/reorganized-string' '/articles/max-chunks-to-make-sorted-ii'
#  '/articles/max-chunks-to-make-sorted-i' '/articles/basic-calculator-iv'
#  '/articles/jewels-and-stones' '/articles/sliding-puzzle'
#  '/articles/minimize-max-distance-to-gas-station'
#  '/articles/global-and-local-inversions' '/articles/split-bst'
#  '/articles/swap-adjacent-in-lr-string' '/articles/swim-in-rising-water'
#  '/articles/k-th-symbol-in-grammar' '/articles/reaching-points'
#  '/articles/rabbits-in-forest' '/articles/transform-to-chessboard'
#  '/articles/minimum-distance-between-bst-nodes'
#  '/articles/letter-case-permutation' '/articles/is-graph-bipartite'
#  '/articles/k-th-smallest-prime-fraction'
#  '/articles/cheapest-flights-within-k-stops' '/articles/rotated-digits'
#  '/articles/escape-the-ghosts' '/articles/domino-and-tromino-tiling'
#  '/articles/custom-sort-string'
#  '/articles/number-of-matching-subsequences'
#  '/articles/preimage-size-of-factorial-zeroes-function'
#  '/articles/valid-tic-tac-toe-state'
#  '/articles/number-of-subarrays-with-bounded-maximum'
#  '/articles/rotate-string' '/articles/all-paths-from-source-to-target'
#  '/articles/smallest-rotation-with-highest-score'
#  '/articles/champagne-tower' '/articles/similar-rgb-color'
#  '/articles/minimum-swaps-to-make-sequences-increasing'
#  '/articles/find-eventual-safe-states' '/articles/bricks-falling-when-hit'
#  '/articles/unique-morse-code-words'
#  '/articles/split-array-with-same-average'
#  '/articles/number-of-lines-to-write-string'
#  '/articles/max-increase-to-keep-city-skyline' '/articles/soup-servings'
#  '/articles/expressive-words' '/articles/chalkboard-xor-game'
#  '/articles/subdomain-visit-count' '/articles/largest-triangle-area'
#  '/articles/largest-sum-of-averages' '/articles/binary-tree-pruning'
#  '/articles/bus-routes' '/articles/ambiguous-coordinates'
#  '/articles/linked-list-components' '/articles/race-car'
#  '/articles/most-common-word' '/articles/short-encoding-of-words'
#  '/articles/shortest-distance-to-a-character'
#  '/articles/card-flipping-game' '/articles/binary-trees-with-factors'
#  '/articles/goat-latin' '/articles/friends-of-appropriate-ages'
#  '/articles/most-profit-assigning-work' '/articles/making-a-large-island'
#  '/articles/unique-letter-string' '/articles/consecutive-numbers-sum'
#  '/articles/positions-of-large-groups'
#  '/articles/masking-personal-information' '/articles/flipping-an-image'
#  '/articles/find-and-replace-in-string'
#  '/articles/sum-of-distances-in-tree' '/articles/image-overlap'
#  '/articles/rectangle-overlap' '/articles/new-21-game'
#  '/articles/push-dominoes' '/articles/similar-string-groups'
#  '/articles/magic-squares-in-grid' '/articles/keys-and-rooms'
#  '/articles/split-array-into-fibonacci-sequence'
#  '/articles/guess-the-word' '/articles/backspace-string-compare'
#  '/articles/longest-mountain-in-array' '/articles/hand-of-straights'
#  '/articles/shortest-path-visiting-all-nodes' '/articles/shifting-letters'
#  '/articles/maximize-distance-to-closest-person'
#  '/articles/rectangle-area-ii' '/articles/loud-and-rich'
#  '/articles/peak-index-in-a-mountain-array' '/articles/car-fleet'
#  '/articles/k-similar-strings' '/articles/exam-room'
#  '/articles/score-of-parentheses'
#  '/articles/minimum-cost-to-hire-k-workers' '/articles/mirror-reflection'
#  '/articles/buddy-strings' '/articles/lemonade-change'
#  '/articles/score-after-flipping-matrix'
#  '/articles/shortest-subarray-with-sum-at-least-k'
#  '/articles/all-nodes-distance-k-in-binary-tree'
#  '/articles/shortest-path-to-get-all-keys'
#  '/articles/smallest-subtree-with-all-the-deepest-nodes'
#  '/articles/prime-palindrome' '/articles/transpose-matrix'
#  '/articles/binary-gap' '/articles/reordered-power-of-2'
#  '/articles/advantage-shuffle'
#  '/articles/minimum-number-of-refueling-stops'
#  '/articles/leaf-similar-trees'
#  '/articles/length-of-longest-fibonacci-subsequence'
#  '/articles/walking-robot-simulation' '/articles/koko-eating-bananas'
#  '/articles/middle-of-the-linked-list' '/articles/stone-game'
#  '/articles/nth-magical-number' '/articles/profitable-schemes'
#  '/articles/decoded-string-at-index' '/articles/boats-to-save-people'
#  '/articles/reachable-nodes-in-subdivided-graph'
#  '/articles/projection-area-of-3d-shapes'
#  '/articles/uncommon-words-from-two-sentences'
#  '/articles/spiral-matrix-iii' '/articles/possible-bipartition'
#  '/articles/super-egg-drop' '/articles/fair-candy-swap'
#  '/articles/construct-binary-tree-from-preorder-and-postorder-traversal'
#  '/articles/find-and-replace-pattern'
#  '/articles/sum-of-subsequence-widths'
#  '/articles/surface-area-of-3d-shapes'
#  '/articles/groups-of-special-equivalent-strings'
#  '/articles/all-possible-full-binary-trees'
#  '/articles/maximum-frequency-stack' '/articles/monotonic-array'
#  '/articles/increasing-order-search-tree'
#  '/articles/bitwise-ors-of-subarrays' '/articles/orderly-queue'
#  '/articles/rle-iterator' '/articles/online-stock-span'
#  '/articles/numbers-at-most-n-given-digit-set'
#  '/articles/valid-permutations-for-di-sequence'
#  '/articles/fruit-into-baskets' '/articles/sort-array-by-parity'
#  '/articles/super-palindromes' '/articles/sum-of-subarray-minimums'
#  '/articles/smallest-range-i' '/articles/snakes-and-ladders'
#  '/articles/smallest-range-ii' '/articles/online-election'
#  '/articles/cat-and-mouse-game' '/articles/x-of-a-kind-in-a-deck-of-cards'
#  '/articles/parition-array-into-disjoint-intervals'
#  '/articles/word-subsets' '/articles/reverse-only-letters'
#  '/articles/maximum-sub-circular-subarray'
#  '/articles/complete-binary-tree-inserter'
#  '/articles/number-of-music-playlists'
#  '/articles/minimum-add-to-make-parentheses-valid'
#  '/articles/sort-array-by-parity-ii' '/articles/3sum-with-multiplicity'
#  '/articles/minimize-malware-spread' '/articles/long-pressed-name'
#  '/articles/flip-string-to-monotone-increasing'
#  '/articles/three-equal-parts' '/articles/minimize-malware-spread-ii'
#  '/articles/unique-email-addresses' '/articles/binary-subarrays-with-sum'
#  '/articles/minimum-path-falling-sum' '/articles/beautiful-array'
#  '/articles/number-of-recent-calls' '/articles/shortest-bridge'
#  '/articles/knight-dialer' '/articles/stamping-the-sequence'
#  '/articles/reorder-data-in-log-files' '/articles/range-sum-of-bst'
#  '/articles/minimum-area-rectangle' '/articles/distinct-subsequences-ii'
#  '/articles/valid-mountain-array' '/articles/di-string-match'
#  '/articles/find-the-shortest-superstring'
#  '/articles/delete-columns-to-make-sorted'
#  '/articles/minimum-increment-to-make-array-unique'
#  '/articles/validate-stack-sequences'
#  '/articles/most-stones-removed-with-same-row-or-column'
#  '/articles/bag-of-tokens' '/articles/largest-time-for-given-digits'
#  '/articles/reveal-cards-in-increasing-order'
#  '/articles/flip-equivalent-binary-trees'
#  '/articles/largest-component-size-by-common-factor'
#  '/articles/verifying-an-alien-dictionary'
#  '/articles/array-of-doubled-pairs'
#  '/articles/delete-columns-to-make-sorted-ii'
#  '/articles/tallest-billboard' '/articles/prison-cells-after-n-days'
#  '/articles/check-completeness-of-a-binary-tree'
#  '/articles/regions-cut-by-slashes'
#  '/articles/delete-columns-to-make-sorted-iii'
#  '/articles/n-repeated-element-in-size-2n-array'
#  '/articles/maximum-width-ramp' '/articles/minimum-area-rectangle-ii'
#  '/articles/least-operators-to-express-number'
#  '/articles/univalued-binary-tree' '/articles/vowel-spellchecker'
#  '/articles/numbers-with-same-consecutive-differences'
#  '/articles/binary-tree-cameras' '/articles/pancake-sorting'
#  '/articles/powerful-integers'
#  '/articles/flip-binary-tree-to-match-preorder-traversal'
#  '/articles/equal-rational-numbers' '/articles/k-closest-points-to-origin'
#  '/articles/subarray-sums-divisible-by-k' '/articles/odd-even-jump'
#  '/articles/largest-perimeter-triangle'
#  '/articles/squares-of-a-sorted-array'
#  '/articles/longest-turbulent-subarray'
#  '/articles/distribute-coins-in-binary-tree' '/articles/unique-paths-iii'
#  '/articles/time-based-key-value-store'
#  '/articles/minimum-cost-for-tickets'
#  '/articles/string-without-aaa-or-bbb'
#  '/articles/sum-of-even-numbers-after-queries'
#  '/articles/interval-list-intersections'
#  '/articles/vertical-order-traversal-of-a-binary-tree'
#  '/articles/smallest-string-starting-from-leaf'
#  '/articles/add-to-array-form-of-integer'
#  '/articles/satisfiability-of-equality-equations'
#  '/articles/broken-calculator'
#  '/articles/subarrays-with-k-different-integers'
#  '/articles/cousins-in-binary-tree' '/articles/rotting-oranges'
#  '/articles/minimum-number-of-k-consecutive-bit-flips'
#  '/articles/number-of-squareful-arrays' '/articles/find-the-town-judge'
#  '/articles/max-consecutive-ones-iii'
#  '/articles/minimum-domino-rotations-for-equal-row'
#  '/articles/construct-bst-from-preorder-traversal'
#  '/articles/complement-of-base-10-integer'
#  '/articles/pairs-of-songs-with-total-durations-divisible-by-60'
#  '/articles/smallest-integer-divisible-by-k'
#  '/articles/sum-root-to-leaf-binary-numbers'
#  '/articles/maximum-difference-between-node-and-ancestor'
#  '/articles/two-city-scheduling' '/articles/stream-of-characters'
#  '/articles/robot-bounded-in-circle'
#  '/articles/longest-duplicate-substring' '/articles/last-stone-weight'
#  '/articles/remove-all-adjacent-duplicates-in-string'
#  '/articles/all-paths-from-source-lead-to-destination'
#  '/articles/missing-element-in-sorted-array'
#  '/articles/longest-repeating-substring'
#  '/articles/number-of-submatrices-that-sum-to-target'
#  '/articles/high-five' '/articles/duplicate-zeros'
#  '/articles/shortest-path-in-a-binary-matrix' '/articles/car-pooling'
#  '/articles/two-sum-less-than-k' '/articles/distribute-candies-to-people'
#  '/articles/print-in-order' '/articles/maximum-average-subtree'
#  '/articles/largest-unique-number' '/articles/armstrong-number'
#  '/articles/connecting-cities-with-minimum-cost'
#  '/articles/parallel-courses' '/articles/n-th-tribonacci-number'
#  '/articles/longest-common-subsequence'
#  '/articles/minimum-swaps-to-group-all-1s-together'
#  '/articles/maximum-level-sum-of-a-binary-tree'
#  '/articles/single-row-keyboard' '/articles/design-file-system'
#  '/articles/minimum-cost-to-connect-sticks'
#  '/articles/count-substrings-with-only-one-distinct-letter'
#  '/articles/shortest-distance-to-target-color'
#  '/articles/critical-connections-in-a-network'
#  '/articles/how-many-apples-can-you-put-into-the-basket'
#  '/articles/find-smallest-common-element-in-all-rows'
#  '/articles/remove-all-adjacent-duplicates-in-string-ii'
#  '/articles/intersection-of-three-sorted-arrays' '/articles/two-sum-bsts'
#  '/articles/valid-palindrome-iii'
#  '/articles/minimum-cost-to-move-chips-to-the-same-position'
#  '/articles/missing-number-in-arithmetic-progression'
#  '/articles/meeting-scheduler' '/articles/design-a-leaderboard'
#  '/articles/tree-diameter'
#  '/articles/minimum-remove-to-make-valid-parentheses'
#  '/articles/shift-2d-grid' '/articles/search-suggestions-system'
#  '/articles/remove-interval'
#  '/articles/find-the-smallest-divisor-given-a-threshold'
#  '/articles/iterator-for-combination' '/articles/remove-covered-intervals'
#  '/articles/convert-binary-number-in-a-linked-list-to-integer'
#  '/articles/sequential-digits' '/articles/deepest-leaves-sum'
#  '/articles/all-elements-in-two-bsts' '/articles/jump-game-iii'
#  '/articles/sort-the-matrix-diagonally'
#  '/articles/remove-palindrome-subsequences'
#  '/articles/the-k-weakest-rows-in-a-matrix'
#  '/articles/reduce-array-size-to-the-half'
#  '/articles/maximum-product-of-splitted-binary-tree'
#  '/articles/number-of-steps-to-reduce-a-number-to-zero'
#  '/articles/angle-between-hands-of-a-clock' '/articles/jump-game-iv'
#  '/articles/construct-target-array-with-multiple-sums'
#  '/articles/find-a-corresponding-node-of-a-binary-tree-in-a-clone-of-that-tree'
#  '/articles/find-lucky-integer-in-an-array'
#  '/articles/design-underground-system' '/articles/counting-elements'
#  '/articles/performing-string-shifts'
#  '/articles/leftmost-column-with-a-at-least-a-one'
#  '/articles/first-unique-number'
#  '/articles/check-if-all-ones-are-at-least-k-places-away'
#  '/articles/consecutive-characters'
#  '/articles/pseudo-palindromic-paths-in-a-binary-tree'
#  '/articles/check-if-a-string-contains-all-binary-codes-of-size-k'
#  '/articles/cherry-pickup-ii'
#  '/articles/delete-n-nodes-after-m-nodes-of-a-linked-list'
#  '/articles/running-sum-of-1d-array'
#  '/articles/clone-binary-tree-with-random-pointer'
#  '/articles/the-kth-factor-of-n' '/articles/find-root-of-n-ary-tree'
#  '/articles/stone-game-iv' '/articles/diameter-of-n-ary-tree'
#  '/articles/kth-missing-positive-number'
#  '/articles/minimum-operations-to-make-array-equal'
#  '/articles/dot-product-of-two-sparse-vectors'
#  '/articles/binary-search-tree-iterator-ii'
#  '/articles/find-nearest-right-node-in-binary-tree'
#  '/articles/path-with-minimum-effort'
#  '/articles/rank-transform-of-a-matrix'
#  '/articles/check-array-formation-through-concatenation'
#  '/articles/count-sorted-vowel-strings'
#  '/articles/furthest-building-you-can-reach'
#  '/articles/get-maximum-in-generated-array'
#  '/articles/create-sorted-array-through-instructions'
#  '/articles/determine-if-two-strings-are-close'
#  '/articles/minimum-operations-to-reduce-x-to-zero'
#  '/articles/check-if-two-string-arrays-are-equivalent'
#  '/articles/smallest-string-with-a-given-numeric-value'
#  '/articles/find-the-most-competitive-subsequence'
#  '/articles/minimize-deviation-in-array'
#  '/articles/max-number-of-k-sum-pairs'
#  '/articles/concatenation-of-consecutive-binary-numbers'
#  '/articles/partitioning-into-minimum-number-of-deci-binary-numbers'
#  '/articles/stone-game-vii' '/articles/maximum-erasure-value'
#  '/articles/jump-game-vi' '/articles/determine-if-string-halves-are-alike'
#  '/articles/maximum-number-of-eaten-apples'
#  '/articles/maximum-units-on-a-truck'
#  '/articles/ways-to-split-array-into-three-subarrays'
#  '/articles/swapping-nodes-in-a-linked-list']
#    id                                           title  \
# 0   1                                         Two Sum
# 1   2                                 Add Two Numbers
# 2   3  Longest Substring Without Repeating Characters
# 3   4                     Median of Two Sorted Arrays
# 4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# 0                                  /articles/two-sum             46.7
# 1                          /articles/add-two-numbers             35.7
# 2  /articles/longest-substring-without-repeating-...             31.5
# 3              /articles/median-of-two-sorted-arrays             31.4
# 4            /articles/longest-palindromic-substring             30.6
#
#    frequency                                                url  \
# 0      100.0              https://leetcode.com/problems/two-sum
# 1       93.1      https://leetcode.com/problems/add-two-numbers
# 2       90.9  https://leetcode.com/problems/longest-substrin...
# 3       86.2  https://leetcode.com/problems/median-of-two-so...
# 4       84.7  https://leetcode.com/problems/longest-palindro...
#
#    discuss_count    accepted  submissions  \
# 0            999   4100000.0    8700000.0
# 1            999   1900000.0    5200000.0
# 2            999   2100000.0    6700000.0
# 3            999  90470000.0    2900000.0
# 4            999   1300000.0    4100000.0
#
#                                            companies  \
# 0  Amazon,Google,Apple,Adobe,Microsoft,Bloomberg,...
# 1  Bloomberg,Microsoft,Amazon,Google,Facebook,App...
# 2  Amazon,Bloomberg,Microsoft,Facebook,Apple,Adob...
# 3  Amazon,Goldman Sachs,Facebook,Microsoft,Apple,...
# 4  Amazon,Microsoft,Wayfair,Facebook,Adobe,eBay,G...
#
#                                   related_topics  likes  dislikes  rating  \
# 0                               Array,Hash Table  20217       712      97
# 1                     Linked List,Math,Recursion  11350      2704      81
# 2  Hash Table,Two Pointers,String,Sliding Window  13810       714      95
# 3         Array,Binary Search,Divide and Conquer   9665      1486      87
# 4                     String,Dynamic Programming  10271       670      94
#
#    asked_by_faang                                  similar_questions
# 0               1  [3Sum, /problems/3sum/, Medium], [4Sum, /probl...
# 1               1  [Multiply Strings, /problems/multiply-strings/...
# 2               1  [Longest Substring with At Most Two Distinct C...
# 3               1                                                NaN
# 4               1  [Shortest Palindrome, /problems/shortest-palin...

# %% [markdown]
# ### Question 7
#
# #### Convert the datatypes for **accepted** and **submissions** columns

# %%
# Write a small function to take M, K and convert to numeric
def convert_to_numeric(number_lit: object) -> float:
    number_lit = str(number_lit)
    if pd.isna(number_lit):
        return np.nan
    number_lit = number_lit.strip().replace(' ', '')
    if 'M' in number_lit:
        return float(number_lit.replace('M', '')) * 1_000_000
    elif 'K' in number_lit:
        return float(number_lit.replace('K', '')) * 100_000
    else:
        return float(number_lit)

# %%
#Solution 7(your code here)
# Convert 'accepted' and 'submissions' to numeric types 
# Apply the function to the 'accepted' and 'submissions' columns
leetcode_df['accepted'] = leetcode_df['accepted'].apply(convert_to_numeric)
leetcode_df['submissions'] = leetcode_df['submissions'].apply(convert_to_numeric)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   object
#  2   description        1825 non-null   object
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   object
#  5   solution_link      1825 non-null   object
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   object
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   float64
#  11  submissions        1825 non-null   float64
#  12  companies          1749 non-null   object
#  13  related_topics     1571 non-null   object
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
#  17  asked_by_faang     1825 non-null   int64
#  18  similar_questions  745 non-null    object
# dtypes: float64(4), int64(7), object(8)
# memory usage: 271.0+ KB
#    id                                           title  \
# 0   1                                         Two Sum
# 1   2                                 Add Two Numbers
# 2   3  Longest Substring Without Repeating Characters
# 3   4                     Median of Two Sorted Arrays
# 4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# 0                                  /articles/two-sum             46.7
# 1                          /articles/add-two-numbers             35.7
# 2  /articles/longest-substring-without-repeating-...             31.5
# 3              /articles/median-of-two-sorted-arrays             31.4
# 4            /articles/longest-palindromic-substring             30.6
#
#    frequency                                                url  \
# 0      100.0              https://leetcode.com/problems/two-sum
# 1       93.1      https://leetcode.com/problems/add-two-numbers
# 2       90.9  https://leetcode.com/problems/longest-substrin...
# 3       86.2  https://leetcode.com/problems/median-of-two-so...
# 4       84.7  https://leetcode.com/problems/longest-palindro...
#
#    discuss_count    accepted  submissions  \
# 0            999   4100000.0    8700000.0
# 1            999   1900000.0    5200000.0
# 2            999   2100000.0    6700000.0
# 3            999  90470000.0    2900000.0
# 4            999   1300000.0    4100000.0
#
#                                            companies  \
# 0  Amazon,Google,Apple,Adobe,Microsoft,Bloomberg,...
# 1  Bloomberg,Microsoft,Amazon,Google,Facebook,App...
# 2  Amazon,Bloomberg,Microsoft,Facebook,Apple,Adob...
# 3  Amazon,Goldman Sachs,Facebook,Microsoft,Apple,...
# 4  Amazon,Microsoft,Wayfair,Facebook,Adobe,eBay,G...
#
#                                   related_topics  likes  dislikes  rating  \
# 0                               Array,Hash Table  20217       712      97
# 1                     Linked List,Math,Recursion  11350      2704      81
# 2  Hash Table,Two Pointers,String,Sliding Window  13810       714      95
# 3         Array,Binary Search,Divide and Conquer   9665      1486      87
# 4                     String,Dynamic Programming  10271       670      94
#
#    asked_by_faang                                  similar_questions
# 0               1  [3Sum, /problems/3sum/, Medium], [4Sum, /probl...
# 1               1  [Multiply Strings, /problems/multiply-strings/...
# 2               1  [Longest Substring with At Most Two Distinct C...
# 3               1                                                NaN
# 4               1  [Shortest Palindrome, /problems/shortest-palin...

# %%
# Verify changes
leetcode_df.info()
leetcode_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1825 non-null   int64
#  1   title              1825 non-null   object
#  2   description        1825 non-null   object
#  3   is_premium         1825 non-null   int64
#  4   difficulty         1825 non-null   object
#  5   solution_link      1825 non-null   object
#  6   acceptance_rate    1825 non-null   float64
#  7   frequency          1825 non-null   float64
#  8   url                1825 non-null   object
#  9   discuss_count      1825 non-null   int64
#  10  accepted           1825 non-null   float64
#  11  submissions        1825 non-null   float64
#  12  companies          1749 non-null   object
#  13  related_topics     1571 non-null   object
#  14  likes              1825 non-null   int64
#  15  dislikes           1825 non-null   int64
#  16  rating             1825 non-null   int64
#  17  asked_by_faang     1825 non-null   int64
#  18  similar_questions  745 non-null    object
# dtypes: float64(4), int64(7), object(8)
# memory usage: 271.0+ KB
#    id                                           title  \
# 0   1                                         Two Sum
# 1   2                                 Add Two Numbers
# 2   3  Longest Substring Without Repeating Characters
# 3   4                     Median of Two Sorted Arrays
# 4   5                   Longest Palindromic Substring
#
#                                          description  is_premium difficulty  \
# 0  Given an array of integers `nums` and an integ...           0       Easy
# 1  You are given two non-empty linked lists repre...           0     Medium
# 2  Given a string `s`, find the length of the lon...           0     Medium
# 3  Given two sorted arrays `nums1` and `nums2` of...           0       Hard
# 4  Given a string `s`, return the longest palindr...           0     Medium
#
#                                        solution_link  acceptance_rate  \
# 0                                  /articles/two-sum             46.7
# 1                          /articles/add-two-numbers             35.7
# 2  /articles/longest-substring-without-repeating-...             31.5
# 3              /articles/median-of-two-sorted-arrays             31.4
# 4            /articles/longest-palindromic-substring             30.6
#
#    frequency                                                url  \
# 0      100.0              https://leetcode.com/problems/two-sum
# 1       93.1      https://leetcode.com/problems/add-two-numbers
# 2       90.9  https://leetcode.com/problems/longest-substrin...
# 3       86.2  https://leetcode.com/problems/median-of-two-so...
# 4       84.7  https://leetcode.com/problems/longest-palindro...
#
#    discuss_count    accepted  submissions  \
# 0            999   4100000.0    8700000.0
# 1            999   1900000.0    5200000.0
# 2            999   2100000.0    6700000.0
# 3            999  90470000.0    2900000.0
# 4            999   1300000.0    4100000.0
#
#                                            companies  \
# 0  Amazon,Google,Apple,Adobe,Microsoft,Bloomberg,...
# 1  Bloomberg,Microsoft,Amazon,Google,Facebook,App...
# 2  Amazon,Bloomberg,Microsoft,Facebook,Apple,Adob...
# 3  Amazon,Goldman Sachs,Facebook,Microsoft,Apple,...
# 4  Amazon,Microsoft,Wayfair,Facebook,Adobe,eBay,G...
#
#                                   related_topics  likes  dislikes  rating  \
# 0                               Array,Hash Table  20217       712      97
# 1                     Linked List,Math,Recursion  11350      2704      81
# 2  Hash Table,Two Pointers,String,Sliding Window  13810       714      95
# 3         Array,Binary Search,Divide and Conquer   9665      1486      87
# 4                     String,Dynamic Programming  10271       670      94
#
#    asked_by_faang                                  similar_questions
# 0               1  [3Sum, /problems/3sum/, Medium], [4Sum, /probl...
# 1               1  [Multiply Strings, /problems/multiply-strings/...
# 2               1  [Longest Substring with At Most Two Distinct C...
# 3               1                                                NaN
# 4               1  [Shortest Palindrome, /problems/shortest-palin...

# %% [markdown]
# ## Question 8
#
# #### Find if duplicates exist based on **id** and **title**

# %%
#Solution 8(your code here)
# Checking for duplicate id

# %%
# Checking for duplicate title

# %% [markdown]
# ##Question 9
# #### Plot the outliers in the dataset.

# %%
#Solution 9(your code here)
# (Hint: select only numbers using .select_dtypes() and .plot as a 'box' plot with 45deg rotation)

# %% [markdown]
# ### Question 10
#
# #### Identify and plot the outliers for the numeric columns

# %%
#Solution 10(your code here)

# %% [markdown]
# ### Question 11
#
# #### Handle the outliers

# %%
#Solution 11(your code here)

# %% [markdown]
# ##Question 12
#
# ####Plot top 20 companies whose problems are listed in this dataset.

# %%
#Solution 12(your code here)

# %% [markdown]
# ### Question 13
# #### Plot Distribution of difficulty

# %%
#Solution 13(your code here)

# %% [markdown]
# The bar plot shows the distribution of problem difficulty levels. It appears that:
#
# - Medium difficulty problems are the most common.
# - Easy and Hard difficulties have fewer problems compared to Medium.

# %% [markdown]
# ### Question 14
#
# #### Plot the distribution of acceptance_rate

# %%
#Solution 14(your code here)
# Plot the distribution of acceptance_rate

# %% [markdown]
# ### Question 15
#
# #### Plot the distribution of frequency

# %%
#Solution 15(your code here)
# Plot the distribution of frequency

# %% [markdown]
# ### Question 16
#
# #### Plot the Scatter plot of likes vs dislikes

# %%
#Solution 16(your code here)
# Scatter plot of likes vs dislikes

# %% [markdown]
# ### Question 17
#
# #### Plot the Scatter plot of accepted vs submissions

# %%
#Solution 17(your code here)
# Scatter plot of accepted vs submissions

# %% [markdown]
# ### Question 18
#
# #### Plot the Bar plot for average acceptance_rate by difficulty

# %%
#Solution 18(your code here)
# Bar plot for average acceptance_rate by difficulty

# %% [markdown]
# ### Question 19
#
# #### Plot a scatter plot for acceptance_rate vs frequency

# %%
#Solution 19(your code here)
# acceptance_rate vs frequency
